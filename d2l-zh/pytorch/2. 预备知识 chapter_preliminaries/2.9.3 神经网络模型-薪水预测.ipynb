# %%
"""引入依赖"""
import torch
import torch.nn as nn
import torch.optim as optim

# %%
"""获取数据集"""
features = torch.tensor([[0, 0, 25, 0], [1, 1, 30, 1], [2, 2, 35, 2], [3, 0, 40, 0], [0, 1, 45, 1]], dtype=torch.float)
labels = torch.tensor([10000, 15000, 20000, 25000, 30000], dtype=torch.float)

# %%
"""定义神经网络模型"""
"""包含两个全连接层和一个ReLU激活函数"""
class Net(nn.Module): # 定义了一个新的类Net，它继承了nn.Module。在PyTorch中，所有的神经网络模型都应该继承nn.Module
    def __init__(self): # 初始化函数，当我们创建类的一个实例时，这个函数会被调用。 
        super(Net, self).__init__() # 调用了父类nn.Module的初始化函数。这是Python面向对象编程的一个常见模式。
        self.fc1 = nn.Linear(4, 10) # 创建了一个全连接层（nn.Linear），并将它赋值给self.fc1。这个全连接层接收4个输入特征，并输出10个特征。
        self.fc2 = nn.Linear(10, 1) # 创建了另一个全连接层，并将它赋值给self.fc2。这个全连接层接收10个输入特征，并输出1个特征。

    def forward(self, x): # 类的前向传播函数，当我们使用神经网络进行预测时，这个函数会被调用。
        x = torch.relu(self.fc1(x)) # 首先使用self.fc1全连接层处理输入x，然后对结果应用ReLU激活函数。
        x = self.fc2(x) # 使用self.fc2全连接层处理上一步的结果
        return x # 返回最后的预测结果

net = Net() # 创建了Net类的一个实例，并将它赋值给net。

# %%
"""定义损失函数和优化器"""
"""定义了一个均方误差损失函数和一个随机梯度下降优化器"""
criterion = nn.MSELoss()
optimizer = optim.SGD(net.parameters(), lr=0.01)

# %%
"""训练模型"""
"""进行了1000次训练迭代"""
"""每次迭代中，我们都会计算模型的输出和损失"""
"""然后使用反向传播和优化器更新模型的参数"""
for epoch in range(1000):
    optimizer.zero_grad()
    outputs = net(features)
    loss = criterion(outputs.squeeze(), labels)
    print(f'第{epoch}训练的损失值为：{loss}')
    loss.backward()
    optimizer.step()
# Out:
# 第0训练的损失值为：449843520.0
# 第1训练的损失值为：1.276663704292688e+18
# 第2训练的损失值为：491534143193088.0
# 第3训练的损失值为：472069351407616.0
# 第4训练的损失值为：453375338479616.0
# 第5训练的损失值为：435421704093696.0
# 第6训练的损失值为：418179021012992.0
# 第7训练的损失值为：401619103514624.0
# 第8训练的损失值为：385715007389696.0
# 第9训练的损失值为：370440761507840.0
# 第10训练的损失值为：355771334262784.0
# 第11训练的损失值为：341682801344512.0
# 第12训练的损失值为：328152110858240.0
# 第13训练的损失值为：315157251096576.0
# 第14训练的损失值为：302677015658496.0
# 第15训练的损失值为：290691037003776.0
# 第16训练的损失值为：279179669012480.0
# 第17训练的损失值为：268124171534336.0
# 第18训练的损失值为：257506458730496.0
# 第19训练的损失值为：247309216514048.0
# 第20训练的损失值为：237515768332288.0
# 第21训练的损失值为：228110142275584.0
# 第22训练的损失值为：219077003968512.0
# 第23训练的损失值为：210401539129344.0
# 第24训练的损失值为：202069654896640.0
# 第25训练的损失值为：194067728171008.0
# 第26训练的损失值为：186382639169536.0
# 第27训练的损失值为：179001888866304.0
# 第28训练的损失值为：171913431220224.0
# 第29训练的损失值为：165105656397824.0
# 第30训练的损失值为：158567474659328.0
# 第31训练的损失值为：152288215695360.0
# 第32训练的损失值为：146257628626944.0
# 第33训练的损失值为：140465806508032.0
# 第34训练的损失值为：134903354097664.0
# 第35训练的损失值为：129561178144768.0
# 第36训练的损失值为：124430546108416.0
# 第37训练的损失值为：119503086157824.0
# 第38训练的损失值为：114770770395136.0
# 第39训练的损失值为：110225856135168.0
# 第40训练的损失值为：105860919459840.0
# 第41训练的损失值为：101668838440960.0
# 第42训练的损失值为：97642742808576.0
# 第43训练的损失值为：93776089448448.0
# 第44训练的损失值为：90062561738752.0
# 第45训练的损失值为：86496077938688.0
# 第46训练的损失值为：83070841520128.0
# 第47训练的损失值为：79781248892928.0
# 第48训练的损失值为：76621897793536.0
# 第49训练的损失值为：73587671171072.0
# 第50训练的损失值为：70673602969600.0
# 第51训练的损失值为：67874932654080.0
# 第52训练的损失值为：65187088433152.0
# 第53训练的损失值为：62605678870528.0
# 第54训练的损失值为：60126497079296.0
# 第55训练的损失值为：57745491361792.0
# 第56训练的损失值为：55458765209600.0
# 第57训练的损失值为：53262606663680.0
# 第58训练的损失值为：51153404428288.0
# 第59训练的损失值为：49127735951360.0
# 第60训练的损失值为：47182275149824.0
# 第61训练的损失值为：45313863712768.0
# 第62训练的损失值为：43519435603968.0
# 第63训练的损失值为：41796071587840.0
# 第64训练的损失值为：40140948897792.0
# 第65训练的损失值为：38551370596352.0
# 第66训练的损失值为：37024740409344.0
# 第67训练的损失值为：35558558531584.0
# 第68训练的损失值为：34150438404096.0
# 第69训练的损失值为：32798087839744.0
# 第70训练的损失值为：31499283857408.0
# 第71训练的损失值为：30251914625024.0
# 第72训练的损失值为：29053939613696.0
# 第73训练的损失值为：27903404277760.0
# 第74训练的损失值为：26798427471872.0
# 第75训练的损失值为：25737209839616.0
# 第76训练的损失值为：24718019133440.0
# 第77训练的损失值为：23739188117504.0
# 第78训练的损失值为：22799118761984.0
# 第79训练的损失值为：21896275951616.0
# 第80训练的损失值为：21029185388544.0
# 第81训练的损失值为：20196433592320.0
# 第82训练的损失值为：19396653219840.0
# 第83训练的损失值为：18628548231168.0
# 第84训练的损失值为：17890860335104.0
# 第85训练的损失值为：17182383669248.0
# 第86训练的损失值为：16501962702848.0
# 第87训练的损失值为：15848488042496.0
# 第88训练的损失值为：15220891189248.0
# 第89训练的损失值为：14618145587200.0
# 第90训练的损失值为：14039268720640.0
# 第91训练的损失值为：13483313725440.0
# 第92训练的损失值为：12949378826240.0
# 第93训练的损失值为：12436585316352.0
# 第94训练的损失值为：11944098529280.0
# 第95训练的损失值为：11471114207232.0
# 第96训练的损失值为：11016859549696.0
# 第97训练的损失值为：10580593213440.0
# 第98训练的损失值为：10161603215360.0
# 第99训练的损失值为：9759205883904.0
# 第100训练的损失值为：9372742713344.0
# 第101训练的损失值为：9001584558080.0
# 第102训练的损失值为：8645124816896.0
# 第103训练的损失值为：8302778908672.0
# 第104训练的损失值为：7973991088128.0
# 第105训练的损失值为：7658223435776.0
# 第106训练的损失值为：7354959527936.0
# 第107训练的损失值为：7063706009600.0
# 第108训练的损失值为：6783985778688.0
# 第109训练的损失值为：6515342180352.0
# 第110训练的损失值为：6257335336960.0
# 第111训练的损失值为：6009546866688.0
# 第112训练的损失值为：5771570970624.0
# 第113训练的损失值为：5543018627072.0
# 第114训练的损失值为：5323517067264.0
# 第115训练的损失值为：5112708202496.0
# 第116训练的损失值为：4910247575552.0
# 第117训练的损失值为：4715802787840.0
# 第118训练的损失值为：4529059790848.0
# 第119训练的损失值为：4349710827520.0
# 第120训练的损失值为：4177464393728.0
# 第121训练的损失值为：4012038422528.0
# 第122训练的损失值为：3853163954176.0
# 第123训练的损失值为：3700580417536.0
# 第124训练的损失值为：3554039300096.0
# 第125训练的损失值为：3413302050816.0
# 第126训练的损失值为：3278136672256.0
# 第127训练的损失值为：3148324798464.0
# 第128训练的损失值为：3023652782080.0
# 第129训练的损失值为：2903918510080.0
# 第130训练的损失值为：2788924850176.0
# 第131训练的损失值为：2678485417984.0
# 第132训练的损失值为：2572419596288.0
# 第133训练的损失值为：2470553583616.0
# 第134训练的损失值为：2372721442816.0
# 第135训练的损失值为：2278763790336.0
# 第136训练的损失值为：2188526354432.0
# 第137训练的损失值为：2101862858752.0
# 第138训练的损失值为：2018631090176.0
# 第139训练的损失值为：1938695127040.0
# 第140训练的损失值为：1861924945920.0
# 第141训练的损失值为：1788194717696.0
# 第142训练的损失值为：1717384249344.0
# 第143训练的损失值为：1649377935360.0
# 第144训练的损失值为：1584064495616.0
# 第145训练的损失值为：1521337630720.0
# 第146训练的损失值为：1461094449152.0
# 第147训练的损失值为：1403237171200.0
# 第148训练的损失值为：1347671031808.0
# 第149训练的损失值为：1294305198080.0
# 第150训练的损失值为：1243052507136.0
# 第151训练的损失值为：1193829728256.0
# 第152训练的损失值为：1146555990016.0
# 第153训练的损失值为：1101154484224.0
# 第154训练的损失值为：1057550761984.0
# 第155训练的损失值为：1015673782272.0
# 第156训练的损失值为：975454994432.0
# 第157训练的损失值为：936828928000.0
# 第158训练的损失值为：899732602880.0
# 第159训练的损失值为：864105201664.0
# 第160训练的损失值为：829888528384.0
# 第161训练的损失值为：797026942976.0
# 第162训练的损失值为：765466640384.0
# 第163训练的损失值为：735156174848.0
# 第164训练的损失值为：706045870080.0
# 第165训练的损失值为：678088540160.0
# 第166训练的损失值为：651238178816.0
# 第167训练的损失值为：625451139072.0
# 第168训练的损失值为：600685281280.0
# 第169训练的损失值为：576900169728.0
# 第170训练的损失值为：554056876032.0
# 第171训练的损失值为：532118175744.0
# 第172训练的损失值为：511048253440.0
# 第173训练的损失值为：490812735488.0
# 第174训练的损失值为：471378591744.0
# 第175训练的损失值为：452713971712.0
# 第176训练的损失值为：434788433920.0
# 第177训练的损失值为：417572814848.0
# 第178训练的损失值为：401038966784.0
# 第179训练的损失值为：385159757824.0
# 第180训练的损失值为：369909432320.0
# 第181训练的损失值为：355263021056.0
# 第182训练的损失值为：341196603392.0
# 第183训练的损失值为：327687176192.0
# 第184训练的损失值为：314712719360.0
# 第185训练的损失值为：302252097536.0
# 第186训练的损失值为：290284830720.0
# 第187训练的损失值为：278791618560.0
# 第188训练的损失值为：267753439232.0
# 第189训练的损失值为：257152385024.0
# 第190训练的损失值为：246971138048.0
# 第191训练的损失值为：237193052160.0
# 第192训练的损失值为：227802218496.0
# 第193训练的损失值为：218783203328.0
# 第194训练的损失值为：210121375744.0
# 第195训练的损失值为：201802547200.0
# 第196训练的损失值为：193813118976.0
# 第197训练的损失值为：186140098560.0
# 第198训练的损失值为：178770952192.0
# 第199训练的损失值为：171693588480.0
# 第200训练的损失值为：164896505856.0
# 第201训练的损失值为：158368595968.0
# 第202训练的损失值为：152099192832.0
# 第203训练的损失值为：146078040064.0
# 第204训练的损失值为：140295323648.0
# 第205训练的损失值为：134741622784.0
# 第206训练的损失值为：129407827968.0
# 第207训练的损失值为：124285247488.0
# 第208训练的损失值为：119365541888.0
# 第209训练的损失值为：114640642048.0
# 第210训练的损失值为：110102863872.0
# 第211训练的损失值为：105744760832.0
# 第212训练的损失值为：101559246848.0
# 第213训练的损失值为：97539489792.0
# 第214训练的损失值为：93678903296.0
# 第215训练的损失值为：89971187712.0
# 第216训练的损失值为：86410313728.0
# 第217训练的损失值为：82990440448.0
# 第218训练的损失值为：79705997312.0
# 第219训练的损失值为：76551610368.0
# 第220训练的损失值为：73522167808.0
# 第221训练的损失值为：70612656128.0
# 第222训练的损失值为：67818381312.0
# 第223训练的损失值为：65134755840.0
# 第224训练的损失值为：62557401088.0
# 第225训练的损失值为：60082106368.0
# 第226训练的损失值为：57704833024.0
# 第227训练的损失值为：55421706240.0
# 第228训练的损失值为：53228982272.0
# 第229训练的损失值为：51123101696.0
# 第230训练的损失值为：49100599296.0
# 第231训练的损失值为：47158198272.0
# 第232训练的损失值为：45292711936.0
# 第233训练的损失值为：43501101056.0
# 第234训练的损失值为：41780436992.0
# 第235训练的损失值为：40127913984.0
# 第236训练的损失值为：38540828672.0
# 第237训练的损失值为：37016592384.0
# 第238训练的损失值为：35552714752.0
# 第239训练的损失值为：34146805760.0
# 第240训练的损失值为：32796569600.0
# 第241训练的损失值为：31499808768.0
# 第242训练的损失值为：30254399488.0
# 第243训练的损失值为：29058306048.0
# 第244训练的损失值为：27909580800.0
# 第245训练的损失值为：26806341632.0
# 第246训练的损失值为：25746790400.0
# 第247训练的损失值为：24729196544.0
# 第248训练的损失值为：23751903232.0
# 第249训练的损失值为：22813302784.0
# 第250训练的损失值为：21911875584.0
# 第251训练的损失值为：21046151168.0
# 第252训练的损失值为：20214700032.0
# 第253训练的损失值为：19416182784.0
# 第254训练的损失值为：18649280512.0
# 第255训练的损失值为：17912748032.0
# 第256训练的损失值为：17205383168.0
# 第257训练的损失值为：16526032896.0
# 第258训练的损失值为：15873581056.0
# 第259训练的损失值为：15246966784.0
# 第260训练的损失值为：14645166080.0
# 第261训练的损失值为：14067195904.0
# 第262训练的损失值为：13512116224.0
# 第263训练的损失值为：12979017728.0
# 第264训练的损失值为：12467027968.0
# 第265训练的损失值为：11975313408.0
# 第266训练的损失值为：11503070208.0
# 第267训练的损失值为：11049529344.0
# 第268训练的损失值为：10613948416.0
# 第269训练的损失值为：10195615744.0
# 第270训练的损失值为：9793849344.0
# 第271训练的损失值为：9407992832.0
# 第272训练的损失值为：9037416448.0
# 第273训练的损失值为：8681515008.0
# 第274训练的损失值为：8339706880.0
# 第275训练的损失值为：8011435008.0
# 第276训练的损失值为：7696162816.0
# 第277训练的损失值为：7393375232.0
# 第278训练的损失值为：7102577152.0
# 第279训练的损失值为：6823295488.0
# 第280训练的损失值为：6555073024.0
# 第281训练的损失值为：6297470976.0
# 第282训练的损失值为：6050070528.0
# 第283训练的损失值为：5812468224.0
# 第284训练的损失值为：5584274432.0
# 第285训练的损失值为：5365115904.0
# 第286训练的损失值为：5154637824.0
# 第287训练的损失值为：4952494592.0
# 第288训练的损失值为：4758355968.0
# 第289训练的损失值为：4571904512.0
# 第290训练的损失值为：4392838144.0
# 第291训练的损失值为：4220861184.0
# 第292训练的损失值为：4055695360.0
# 第293训练的损失值为：3897069568.0
# 第294训练的损失值为：3744725504.0
# 第295训练的损失值为：3598414592.0
# 第296训练的损失值为：3457897216.0
# 第297训练的损失值为：3322944768.0
# 第298训练的损失值为：3193336320.0
# 第299训练的损失值为：3068860416.0
# 第300训练的损失值为：2949313280.0
# 第301训练的损失值为：2834500608.0
# 第302训练的损失值为：2724234496.0
# 第303训练的损失值为：2618334720.0
# 第304训练的损失值为：2516628480.0
# 第305训练的损失值为：2418950400.0
# 第306训练的损失值为：2325139968.0
# 第307训练的损失值为：2235044352.0
# 第308训练的损失值为：2148516864.0
# 第309训练的损失值为：2065415168.0
# 第310训练的损失值为：1985604864.0
# 第311训练的损失值为：1908955136.0
# 第312训练的损失值为：1835340416.0
# 第313训练的损失值为：1764640512.0
# 第314训练的损失值为：1696740864.0
# 第315训练的损失值为：1631529856.0
# 第316训练的损失值为：1568901376.0
# 第317训练的损失值为：1508753024.0
# 第318训练的损失值为：1450986240.0
# 第319训练的损失值为：1395507200.0
# 第320训练的损失值为：1342225024.0
# 第321训练的损失值为：1291052928.0
# 第322训练的损失值为：1241907328.0
# 第323训练的损失值为：1194707840.0
# 第324训练的损失值为：1149377280.0
# 第325训练的损失值为：1105841920.0
# 第326训练的损失值为：1064030848.0
# 第327训练的损失值为：1023875200.0
# 第328训练的损失值为：985309568.0
# 第329训练的损失值为：948271424.0
# 第330训练的损失值为：912699904.0
# 第331训练的损失值为：878536896.0
# 第332训练的损失值为：845726912.0
# 第333训练的损失值为：814216000.0
# 第334训练的损失值为：783953088.0
# 第335训练的损失值为：754888576.0
# 第336训练的损失值为：726974912.0
# 第337训练的损失值为：700166720.0
# 第338训练的损失值为：674420096.0
# 第339训练的损失值为：649693184.0
# 第340训练的损失值为：625945216.0
# 第341训练的损失值为：603137856.0
# 第342训练的损失值为：581233536.0
# 第343训练的损失值为：560196736.0
# 第344训练的损失值为：539992896.0
# 第345训练的损失值为：520589216.0
# 第346训练的损失值为：501953952.0
# 第347训练的损失值为：484056512.0
# 第348训练的损失值为：466867872.0
# 第349训练的损失值为：450359904.0
# 第350训练的损失值为：434505664.0
# 第351训练的损失值为：419279200.0
# 第352训练的损失值为：404655776.0
# 第353训练的损失值为：390611392.0
# 第354训练的损失值为：377123200.0
# 第355训练的损失值为：364169120.0
# 第356训练的损失值为：351728032.0
# 第357训练的损失值为：339779616.0
# 第358训练的损失值为：328304320.0
# 第359训练的损失值为：317283456.0
# 第360训练的损失值为：306699040.0
# 第361训练的损失值为：296533760.0
# 第362训练的损失值为：286771008.0
# 第363训练的损失值为：277394880.0
# 第364训练的损失值为：268390096.0
# 第365训练的损失值为：259741792.0
# 第366训练的损失值为：251436032.0
# 第367训练的损失值为：243459200.0
# 第368训练的损失值为：235798192.0
# 第369训练的损失值为：228440544.0
# 第370训练的损失值为：221374336.0
# 第371训练的损失值为：214587904.0
# 第372训练的损失值为：208070224.0
# 第373训练的损失值为：201810656.0
# 第374训练的损失值为：195798944.0
# 第375训练的损失值为：190025296.0
# 第376训练的损失值为：184480304.0
# 第377训练的损失值为：179154864.0
# 第378训练的损失值为：174040352.0
# 第379训练的损失值为：169128336.0
# 第380训练的损失值为：164410848.0
# 第381训练的损失值为：159880176.0
# 第382训练的损失值为：155528928.0
# 第383训练的损失值为：151349984.0
# 第384训练的损失值为：147336528.0
# 第385训练的损失值为：143482016.0
# 第386训练的损失值为：139780128.0
# 第387训练的损失值为：136224816.0
# 第388训练的损失值为：132810320.0
# 第389训练的损失值为：129531032.0
# 第390训练的损失值为：126381592.0
# 第391训练的损失值为：123356888.0
# 第392训练的损失值为：120451968.0
# 第393训练的损失值为：117662080.0
# 第394训练的损失值为：114982680.0
# 第395训练的损失值为：112409360.0
# 第396训练的损失值为：109937944.0
# 第397训练的损失值为：107564400.0
# 第398训练的损失值为：105284864.0
# 第399训练的损失值为：103095576.0
# 第400训练的损失值为：100992992.0
# 第401训练的损失值为：98973672.0
# 第402训练的损失值为：97034304.0
# 第403训练的损失值为：95171760.0
# 第404训练的损失值为：93382960.0
# 第405训练的损失值为：91665000.0
# 第406训练的损失值为：90015064.0
# 第407训练的损失值为：88430472.0
# 第408训练的损失值为：86908624.0
# 第409训练的损失值为：85447040.0
# 第410训练的损失值为：84043336.0
# 第411训练的损失值为：82695216.0
# 第412训练的损失值为：81400496.0
# 第413训练的损失值为：80157032.0
# 第414训练的损失值为：78962800.0
# 第415训练的损失值为：77815896.0
# 第416训练的损失值为：76714384.0
# 第417训练的损失值为：75656496.0
# 第418训练的损失值为：74640488.0
# 第419训练的损失值为：73664728.0
# 第420训练的损失值为：72727600.0
# 第421训练的损失值为：71827600.0
# 第422训练的损失值为：70963216.0
# 第423训练的损失值为：70133072.0
# 第424训练的损失值为：69335792.0
# 第425训练的损失值为：68570096.0
# 第426训练的损失值为：67834720.0
# 第427训练的损失值为：67128464.0
# 第428训练的损失值为：66450176.0
# 第429训练的损失值为：65798752.0
# 第430训练的损失值为：65173120.0
# 第431训练的损失值为：64572268.0
# 第432训练的损失值为：63995200.0
# 第433训练的损失值为：63441000.0
# 第434训练的损失值为：62908736.0
# 第435训练的损失值为：62397548.0
# 第436训练的损失值为：61906612.0
# 第437训练的损失值为：61435104.0
# 第438训练的损失值为：60982284.0
# 第439训练的损失值为：60547384.0
# 第440训练的损失值为：60129708.0
# 第441训练的损失值为：59728576.0
# 第442训练的损失值为：59343328.0
# 第443训练的损失值为：58973332.0
# 第444训练的损失值为：58617996.0
# 第445训练的损失值为：58276724.0
# 第446训练的损失值为：57948960.0
# 第447训练的损失值为：57634184.0
# 第448训练的损失值为：57331864.0
# 第449训练的损失值为：57041528.0
# 第450训练的损失值为：56762680.0
# 第451训练的损失值为：56494880.0
# 第452训练的损失值为：56237684.0
# 第453训练的损失值为：55990668.0
# 第454训练的损失值为：55753440.0
# 第455训练的损失值为：55525600.0
# 第456训练的损失值为：55306784.0
# 第457训练的损失值为：55096640.0
# 第458训练的损失值为：54894808.0
# 第459训练的损失值为：54700972.0
# 第460训练的损失值为：54514816.0
# 第461训练的损失值为：54336032.0
# 第462训练的损失值为：54164320.0
# 第463训练的损失值为：53999424.0
# 第464训练的损失值为：53841036.0
# 第465训练的损失值为：53688936.0
# 第466训练的损失值为：53542848.0
# 第467训练的损失值为：53402560.0
# 第468训练的损失值为：53267808.0
# 第469训练的损失值为：53138408.0
# 第470训练的损失值为：53014124.0
# 第471训练的损失值为：52894760.0
# 第472训练的损失值为：52780136.0
# 第473训练的损失值为：52670036.0
# 第474训练的损失值为：52564304.0
# 第475训练的损失值为：52462760.0
# 第476训练的损失值为：52365236.0
# 第477训练的损失值为：52271572.0
# 第478训练的损失值为：52181624.0
# 第479训练的损失值为：52095228.0
# 第480训练的损失值为：52012256.0
# 第481训练的损失值为：51932576.0
# 第482训练的损失值为：51856044.0
# 第483训练的损失值为：51782548.0
# 第484训练的损失值为：51711952.0
# 第485训练的损失值为：51644160.0
# 第486训练的损失值为：51579056.0
# 第487训练的损失值为：51516520.0
# 第488训练的损失值为：51456464.0
# 第489训练的损失值为：51398792.0
# 第490训练的损失值为：51343400.0
# 第491训练的损失值为：51290200.0
# 第492训练的损失值为：51239104.0
# 第493训练的损失值为：51190036.0
# 第494训练的损失值为：51142912.0
# 第495训练的损失值为：51097648.0
# 第496训练的损失值为：51054188.0
# 第497训练的损失值为：51012440.0
# 第498训练的损失值为：50972352.0
# 第499训练的损失值为：50933844.0
# 第500训练的损失值为：50896868.0
# 第501训练的损失值为：50861344.0
# 第502训练的损失值为：50827240.0
# 第503训练的损失值为：50794480.0
# 第504训练的损失值为：50763020.0
# 第505训练的损失值为：50732800.0
# 第506训练的损失值为：50703784.0
# 第507训练的损失值为：50675912.0
# 第508训练的损失值为：50649144.0
# 第509训练的损失值为：50623440.0
# 第510训练的损失值为：50598752.0
# 第511训练的损失值为：50575044.0
# 第512训练的损失值为：50552272.0
# 第513训练的损失值为：50530400.0
# 第514训练的损失值为：50509392.0
# 第515训练的损失值为：50489224.0
# 第516训练的损失值为：50469852.0
# 第517训练的损失值为：50451244.0
# 第518训练的损失值为：50433376.0
# 第519训练的损失值为：50416216.0
# 第520训练的损失值为：50399732.0
# 第521训练的损失值为：50383904.0
# 第522训练的损失值为：50368700.0
# 第523训练的损失值为：50354096.0
# 第524训练的损失值为：50340076.0
# 第525训练的损失值为：50326608.0
# 第526训练的损失值为：50313676.0
# 第527训练的损失值为：50301256.0
# 第528训练的损失值为：50289324.0
# 第529训练的损失值为：50277872.0
# 第530训练的损失值为：50266864.0
# 第531训练的损失值为：50256300.0
# 第532训练的损失值为：50246144.0
# 第533训练的损失值为：50236400.0
# 第534训练的损失值为：50227040.0
# 第535训练的损失值为：50218048.0
# 第536训练的损失值为：50209416.0
# 第537训练的损失值为：50201124.0
# 第538训练的损失值为：50193152.0
# 第539训练的损失值为：50185504.0
# 第540训练的损失值为：50178164.0
# 第541训练的损失值为：50171108.0
# 第542训练的损失值为：50164336.0
# 第543训练的损失值为：50157824.0
# 第544训练的损失值为：50151572.0
# 第545训练的损失值为：50145568.0
# 第546训练的损失值为：50139808.0
# 第547训练的损失值为：50134272.0
# 第548训练的损失值为：50128952.0
# 第549训练的损失值为：50123848.0
# 第550训练的损失值为：50118944.0
# 第551训练的损失值为：50114232.0
# 第552训练的损失值为：50109712.0
# 第553训练的损失值为：50105364.0
# 第554训练的损失值为：50101192.0
# 第555训练的损失值为：50097184.0
# 第556训练的损失值为：50093336.0
# 第557训练的损失值为：50089640.0
# 第558训练的损失值为：50086092.0
# 第559训练的损失值为：50082684.0
# 第560训练的损失值为：50079404.0
# 第561训练的损失值为：50076260.0
# 第562训练的损失值为：50073240.0
# 第563训练的损失值为：50070340.0
# 第564训练的损失值为：50067560.0
# 第565训练的损失值为：50064880.0
# 第566训练的损失值为：50062312.0
# 第567训练的损失值为：50059840.0
# 第568训练的损失值为：50057476.0
# 第569训练的损失值为：50055200.0
# 第570训练的损失值为：50053012.0
# 第571训练的损失值为：50050912.0
# 第572训练的损失值为：50048896.0
# 第573训练的损失值为：50046964.0
# 第574训练的损失值为：50045100.0
# 第575训练的损失值为：50043316.0
# 第576训练的损失值为：50041600.0
# 第577训练的损失值为：50039952.0
# 第578训练的损失值为：50038368.0
# 第579训练的损失值为：50036848.0
# 第580训练的损失值为：50035392.0
# 第581训练的损失值为：50033984.0
# 第582训练的损失值为：50032640.0
# 第583训练的损失值为：50031344.0
# 第584训练的损失值为：50030112.0
# 第585训练的损失值为：50028920.0
# 第586训练的损失值为：50027772.0
# 第587训练的损失值为：50026672.0
# 第588训练的损失值为：50025616.0
# 第589训练的损失值为：50024604.0
# 第590训练的损失值为：50023628.0
# 第591训练的损失值为：50022688.0
# 第592训练的损失值为：50021792.0
# 第593训练的损失值为：50020928.0
# 第594训练的损失值为：50020096.0
# 第595训练的损失值为：50019308.0
# 第596训练的损失值为：50018540.0
# 第597训练的损失值为：50017808.0
# 第598训练的损失值为：50017104.0
# 第599训练的损失值为：50016428.0
# 第600训练的损失值为：50015776.0
# 第601训练的损失值为：50015148.0
# 第602训练的损失值为：50014548.0
# 第603训练的损失值为：50013972.0
# 第604训练的损失值为：50013424.0
# 第605训练的损失值为：50012892.0
# 第606训练的损失值为：50012380.0
# 第607训练的损失值为：50011888.0
# 第608训练的损失值为：50011416.0
# 第609训练的损失值为：50010964.0
# 第610训练的损失值为：50010532.0
# 第611训练的损失值为：50010116.0
# 第612训练的损失值为：50009712.0
# 第613训练的损失值为：50009332.0
# 第614训练的损失值为：50008960.0
# 第615训练的损失值为：50008604.0
# 第616训练的损失值为：50008268.0
# 第617训练的损失值为：50007936.0
# 第618训练的损失值为：50007616.0
# 第619训练的损失值为：50007320.0
# 第620训练的损失值为：50007032.0
# 第621训练的损失值为：50006752.0
# 第622训练的损失值为：50006484.0
# 第623训练的损失值为：50006224.0
# 第624训练的损失值为：50005984.0
# 第625训练的损失值为：50005744.0
# 第626训练的损失值为：50005516.0
# 第627训练的损失值为：50005300.0
# 第628训练的损失值为：50005088.0
# 第629训练的损失值为：50004888.0
# 第630训练的损失值为：50004692.0
# 第631训练的损失值为：50004512.0
# 第632训练的损失值为：50004328.0
# 第633训练的损失值为：50004160.0
# 第634训练的损失值为：50003996.0
# 第635训练的损失值为：50003840.0
# 第636训练的损失值为：50003680.0
# 第637训练的损失值为：50003536.0
# 第638训练的损失值为：50003396.0
# 第639训练的损失值为：50003264.0
# 第640训练的损失值为：50003132.0
# 第641训练的损失值为：50003008.0
# 第642训练的损失值为：50002896.0
# 第643训练的损失值为：50002776.0
# 第644训练的损失值为：50002664.0
# 第645训练的损失值为：50002560.0
# 第646训练的损失值为：50002460.0
# 第647训练的损失值为：50002360.0
# 第648训练的损失值为：50002268.0
# 第649训练的损失值为：50002176.0
# 第650训练的损失值为：50002096.0
# 第651训练的损失值为：50002008.0
# 第652训练的损失值为：50001932.0
# 第653训练的损失值为：50001856.0
# 第654训练的损失值为：50001776.0
# 第655训练的损失值为：50001708.0
# 第656训练的损失值为：50001640.0
# 第657训练的损失值为：50001576.0
# 第658训练的损失值为：50001516.0
# 第659训练的损失值为：50001456.0
# 第660训练的损失值为：50001392.0
# 第661训练的损失值为：50001340.0
# 第662训练的损失值为：50001288.0
# 第663训练的损失值为：50001236.0
# 第664训练的损失值为：50001184.0
# 第665训练的损失值为：50001136.0
# 第666训练的损失值为：50001096.0
# 第667训练的损失值为：50001056.0
# 第668训练的损失值为：50001012.0
# 第669训练的损失值为：50000972.0
# 第670训练的损失值为：50000936.0
# 第671训练的损失值为：50000896.0
# 第672训练的损失值为：50000860.0
# 第673训练的损失值为：50000828.0
# 第674训练的损失值为：50000792.0
# 第675训练的损失值为：50000764.0
# 第676训练的损失值为：50000732.0
# 第677训练的损失值为：50000700.0
# 第678训练的损失值为：50000676.0
# 第679训练的损失值为：50000648.0
# 第680训练的损失值为：50000624.0
# 第681训练的损失值为：50000596.0
# 第682训练的损失值为：50000576.0
# 第683训练的损失值为：50000552.0
# 第684训练的损失值为：50000528.0
# 第685训练的损失值为：50000512.0
# 第686训练的损失值为：50000488.0
# 第687训练的损失值为：50000464.0
# 第688训练的损失值为：50000448.0
# 第689训练的损失值为：50000432.0
# 第690训练的损失值为：50000416.0
# 第691训练的损失值为：50000400.0
# 第692训练的损失值为：50000384.0
# 第693训练的损失值为：50000368.0
# 第694训练的损失值为：50000352.0
# 第695训练的损失值为：50000340.0
# 第696训练的损失值为：50000324.0
# 第697训练的损失值为：50000312.0
# 第698训练的损失值为：50000304.0
# 第699训练的损失值为：50000292.0
# 第700训练的损失值为：50000276.0
# 第701训练的损失值为：50000268.0
# 第702训练的损失值为：50000256.0
# 第703训练的损失值为：50000244.0
# 第704训练的损失值为：50000240.0
# 第705训练的损失值为：50000224.0
# 第706训练的损失值为：50000216.0
# 第707训练的损失值为：50000208.0
# 第708训练的损失值为：50000200.0
# 第709训练的损失值为：50000192.0
# 第710训练的损失值为：50000188.0
# 第711训练的损失值为：50000176.0
# 第712训练的损失值为：50000176.0
# 第713训练的损失值为：50000164.0
# 第714训练的损失值为：50000156.0
# 第715训练的损失值为：50000148.0
# 第716训练的损失值为：50000144.0
# 第717训练的损失值为：50000144.0
# 第718训练的损失值为：50000132.0
# 第719训练的损失值为：50000128.0
# 第720训练的损失值为：50000124.0
# 第721训练的损失值为：50000120.0
# 第722训练的损失值为：50000116.0
# 第723训练的损失值为：50000108.0
# 第724训练的损失值为：50000108.0
# 第725训练的损失值为：50000104.0
# 第726训练的损失值为：50000096.0
# 第727训练的损失值为：50000096.0
# 第728训练的损失值为：50000096.0
# 第729训练的损失值为：50000088.0
# 第730训练的损失值为：50000084.0
# 第731训练的损失值为：50000080.0
# 第732训练的损失值为：50000080.0
# 第733训练的损失值为：50000072.0
# 第734训练的损失值为：50000072.0
# 第735训练的损失值为：50000064.0
# 第736训练的损失值为：50000064.0
# 第737训练的损失值为：50000064.0
# 第738训练的损失值为：50000060.0
# 第739训练的损失值为：50000064.0
# 第740训练的损失值为：50000056.0
# 第741训练的损失值为：50000048.0
# 第742训练的损失值为：50000052.0
# 第743训练的损失值为：50000052.0
# 第744训练的损失值为：50000044.0
# 第745训练的损失值为：50000048.0
# 第746训练的损失值为：50000048.0
# 第747训练的损失值为：50000048.0
# 第748训练的损失值为：50000040.0
# 第749训练的损失值为：50000040.0
# 第750训练的损失值为：50000036.0
# 第751训练的损失值为：50000036.0
# 第752训练的损失值为：50000032.0
# 第753训练的损失值为：50000032.0
# 第754训练的损失值为：50000032.0
# 第755训练的损失值为：50000028.0
# 第756训练的损失值为：50000032.0
# 第757训练的损失值为：50000032.0
# 第758训练的损失值为：50000032.0
# 第759训练的损失值为：50000028.0
# 第760训练的损失值为：50000024.0
# 第761训练的损失值为：50000024.0
# 第762训练的损失值为：50000020.0
# 第763训练的损失值为：50000020.0
# 第764训练的损失值为：50000020.0
# 第765训练的损失值为：50000016.0
# 第766训练的损失值为：50000020.0
# 第767训练的损失值为：50000016.0
# 第768训练的损失值为：50000016.0
# 第769训练的损失值为：50000016.0
# 第770训练的损失值为：50000016.0
# 第771训练的损失值为：50000016.0
# 第772训练的损失值为：50000016.0
# 第773训练的损失值为：50000012.0
# 第774训练的损失值为：50000016.0
# 第775训练的损失值为：50000012.0
# 第776训练的损失值为：50000016.0
# 第777训练的损失值为：50000016.0
# 第778训练的损失值为：50000016.0
# 第779训练的损失值为：50000012.0
# 第780训练的损失值为：50000012.0
# 第781训练的损失值为：50000016.0
# 第782训练的损失值为：50000012.0
# 第783训练的损失值为：50000012.0
# 第784训练的损失值为：50000008.0
# 第785训练的损失值为：50000008.0
# 第786训练的损失值为：50000008.0
# 第787训练的损失值为：50000008.0
# 第788训练的损失值为：50000008.0
# 第789训练的损失值为：50000008.0
# 第790训练的损失值为：50000008.0
# 第791训练的损失值为：50000008.0
# 第792训练的损失值为：50000000.0
# 第793训练的损失值为：50000000.0
# 第794训练的损失值为：50000004.0
# 第795训练的损失值为：50000000.0
# 第796训练的损失值为：50000004.0
# 第797训练的损失值为：50000004.0
# 第798训练的损失值为：50000004.0
# 第799训练的损失值为：50000008.0
# 第800训练的损失值为：50000000.0
# 第801训练的损失值为：50000000.0
# 第802训练的损失值为：50000008.0
# 第803训练的损失值为：50000004.0
# 第804训练的损失值为：50000004.0
# 第805训练的损失值为：50000000.0
# 第806训练的损失值为：50000004.0
# 第807训练的损失值为：50000000.0
# 第808训练的损失值为：50000000.0
# 第809训练的损失值为：50000004.0
# 第810训练的损失值为：50000004.0
# 第811训练的损失值为：50000004.0
# 第812训练的损失值为：50000004.0
# 第813训练的损失值为：50000004.0
# 第814训练的损失值为：50000000.0
# 第815训练的损失值为：50000000.0
# 第816训练的损失值为：50000000.0
# 第817训练的损失值为：50000000.0
# 第818训练的损失值为：50000000.0
# 第819训练的损失值为：50000000.0
# 第820训练的损失值为：50000000.0
# 第821训练的损失值为：50000000.0
# 第822训练的损失值为：50000000.0
# 第823训练的损失值为：50000000.0
# 第824训练的损失值为：50000000.0
# 第825训练的损失值为：50000004.0
# 第826训练的损失值为：50000000.0
# 第827训练的损失值为：50000000.0
# 第828训练的损失值为：50000000.0
# 第829训练的损失值为：50000000.0
# 第830训练的损失值为：50000000.0
# 第831训练的损失值为：50000000.0
# 第832训练的损失值为：50000000.0
# 第833训练的损失值为：50000000.0
# 第834训练的损失值为：50000000.0
# 第835训练的损失值为：50000000.0
# 第836训练的损失值为：50000004.0
# 第837训练的损失值为：50000000.0
# 第838训练的损失值为：50000000.0
# 第839训练的损失值为：50000000.0
# 第840训练的损失值为：50000000.0
# 第841训练的损失值为：50000000.0
# 第842训练的损失值为：50000000.0
# 第843训练的损失值为：50000004.0
# 第844训练的损失值为：50000000.0
# 第845训练的损失值为：50000000.0
# 第846训练的损失值为：50000000.0
# 第847训练的损失值为：50000000.0
# 第848训练的损失值为：50000000.0
# 第849训练的损失值为：50000000.0
# 第850训练的损失值为：50000000.0
# 第851训练的损失值为：50000000.0
# 第852训练的损失值为：50000000.0
# 第853训练的损失值为：50000000.0
# 第854训练的损失值为：50000000.0
# 第855训练的损失值为：50000000.0
# 第856训练的损失值为：50000000.0
# 第857训练的损失值为：50000000.0
# 第858训练的损失值为：50000000.0
# 第859训练的损失值为：50000000.0
# 第860训练的损失值为：50000000.0
# 第861训练的损失值为：50000000.0
# 第862训练的损失值为：50000000.0
# 第863训练的损失值为：50000000.0
# 第864训练的损失值为：50000000.0
# 第865训练的损失值为：50000000.0
# 第866训练的损失值为：50000000.0
# 第867训练的损失值为：50000000.0
# 第868训练的损失值为：50000000.0
# 第869训练的损失值为：50000000.0
# 第870训练的损失值为：50000000.0
# 第871训练的损失值为：50000000.0
# 第872训练的损失值为：50000000.0
# 第873训练的损失值为：50000000.0
# 第874训练的损失值为：50000000.0
# 第875训练的损失值为：50000000.0
# 第876训练的损失值为：50000000.0
# 第877训练的损失值为：50000000.0
# 第878训练的损失值为：50000000.0
# 第879训练的损失值为：50000000.0
# 第880训练的损失值为：50000000.0
# 第881训练的损失值为：50000004.0
# 第882训练的损失值为：50000000.0
# 第883训练的损失值为：50000000.0
# 第884训练的损失值为：50000000.0
# 第885训练的损失值为：50000000.0
# 第886训练的损失值为：50000000.0
# 第887训练的损失值为：50000000.0
# 第888训练的损失值为：50000000.0
# 第889训练的损失值为：50000000.0
# 第890训练的损失值为：50000000.0
# 第891训练的损失值为：50000000.0
# 第892训练的损失值为：50000000.0
# 第893训练的损失值为：50000000.0
# 第894训练的损失值为：50000000.0
# 第895训练的损失值为：50000000.0
# 第896训练的损失值为：50000000.0
# 第897训练的损失值为：50000000.0
# 第898训练的损失值为：50000000.0
# 第899训练的损失值为：50000000.0
# 第900训练的损失值为：50000000.0
# 第901训练的损失值为：50000000.0
# 第902训练的损失值为：50000000.0
# 第903训练的损失值为：50000000.0
# 第904训练的损失值为：50000000.0
# 第905训练的损失值为：50000000.0
# 第906训练的损失值为：50000000.0
# 第907训练的损失值为：50000000.0
# 第908训练的损失值为：50000000.0
# 第909训练的损失值为：50000000.0
# 第910训练的损失值为：50000000.0
# 第911训练的损失值为：50000000.0
# 第912训练的损失值为：50000000.0
# 第913训练的损失值为：50000000.0
# 第914训练的损失值为：50000000.0
# 第915训练的损失值为：50000000.0
# 第916训练的损失值为：50000000.0
# 第917训练的损失值为：50000000.0
# 第918训练的损失值为：50000000.0
# 第919训练的损失值为：50000000.0
# 第920训练的损失值为：50000000.0
# 第921训练的损失值为：50000000.0
# 第922训练的损失值为：50000000.0
# 第923训练的损失值为：50000000.0
# 第924训练的损失值为：50000000.0
# 第925训练的损失值为：50000000.0
# 第926训练的损失值为：50000000.0
# 第927训练的损失值为：50000000.0
# 第928训练的损失值为：50000000.0
# 第929训练的损失值为：50000000.0
# 第930训练的损失值为：50000000.0
# 第931训练的损失值为：50000000.0
# 第932训练的损失值为：50000000.0
# 第933训练的损失值为：50000000.0
# 第934训练的损失值为：50000000.0
# 第935训练的损失值为：50000000.0
# 第936训练的损失值为：50000000.0
# 第937训练的损失值为：50000000.0
# 第938训练的损失值为：50000000.0
# 第939训练的损失值为：50000000.0
# 第940训练的损失值为：50000000.0
# 第941训练的损失值为：50000000.0
# 第942训练的损失值为：50000000.0
# 第943训练的损失值为：50000000.0
# 第944训练的损失值为：50000000.0
# 第945训练的损失值为：50000000.0
# 第946训练的损失值为：50000000.0
# 第947训练的损失值为：50000000.0
# 第948训练的损失值为：50000000.0
# 第949训练的损失值为：50000000.0
# 第950训练的损失值为：50000000.0
# 第951训练的损失值为：50000000.0
# 第952训练的损失值为：50000000.0
# 第953训练的损失值为：50000000.0
# 第954训练的损失值为：50000000.0
# 第955训练的损失值为：50000000.0
# 第956训练的损失值为：50000000.0
# 第957训练的损失值为：50000000.0
# 第958训练的损失值为：50000000.0
# 第959训练的损失值为：50000000.0
# 第960训练的损失值为：50000000.0
# 第961训练的损失值为：50000000.0
# 第962训练的损失值为：50000000.0
# 第963训练的损失值为：50000000.0
# 第964训练的损失值为：50000000.0
# 第965训练的损失值为：50000000.0
# 第966训练的损失值为：50000000.0
# 第967训练的损失值为：50000000.0
# 第968训练的损失值为：50000000.0
# 第969训练的损失值为：50000000.0
# 第970训练的损失值为：50000000.0
# 第971训练的损失值为：50000000.0
# 第972训练的损失值为：50000000.0
# 第973训练的损失值为：50000000.0
# 第974训练的损失值为：50000000.0
# 第975训练的损失值为：50000000.0
# 第976训练的损失值为：50000000.0
# 第977训练的损失值为：50000000.0
# 第978训练的损失值为：50000000.0
# 第979训练的损失值为：50000000.0
# 第980训练的损失值为：50000000.0
# 第981训练的损失值为：50000000.0
# 第982训练的损失值为：50000000.0
# 第983训练的损失值为：50000000.0
# 第984训练的损失值为：50000000.0
# 第985训练的损失值为：50000000.0
# 第986训练的损失值为：50000000.0
# 第987训练的损失值为：50000000.0
# 第988训练的损失值为：50000000.0
# 第989训练的损失值为：50000000.0
# 第990训练的损失值为：50000000.0
# 第991训练的损失值为：50000000.0
# 第992训练的损失值为：50000000.0
# 第993训练的损失值为：50000000.0
# 第994训练的损失值为：50000000.0
# 第995训练的损失值为：50000000.0
# 第996训练的损失值为：50000000.0
# 第997训练的损失值为：50000000.0
# 第998训练的损失值为：50000000.0
# 第999训练的损失值为：50000000.0

# %%
"""预测"""
with torch.no_grad():
    test_features = torch.tensor([[1, 2, 40, 1]], dtype=torch.float)
    prediction = net(test_features)
    print(prediction)
# Out:
# tensor([[19999.9531]])
